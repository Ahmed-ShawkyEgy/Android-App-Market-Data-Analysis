# %% [markdown]
# <h2>Import dependencies</h2>

# %%
import pandas as pd
import numpy as np
import datetime # to handle date/time attributes
from os import listdir # os is a module for interacting with the OS
from os.path import isfile, join # to verify file object, and concatenate paths
import glob # to find pathnames matching a specific pattern
import re # regular expressions :)

# set seed for reproducibility
np.random.seed(0)

# %% [markdown]
# <h2>Import data</h2>

# %%
apps_df = pd.read_csv("./data/googleplaystore.csv")
apps_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play    15-Jan-18               2.0.0  4.0.3 and up
# 2               Art & Design     1-Aug-18               1.2.4  4.0.3 and up
# 3               Art & Design     8-Jun-18  Varies with device    4.2 and up
# 4    Art & Design;Creativity    20-Jun-18                 1.1    4.4 and up

# %% [markdown]
# <h2>Explore Data Types</h2>

# %%
print("Shape of data (rows,columns): ",apps_df.shape)
print(apps_df.dtypes)
# Out:
# Shape of data (rows,columns):  (10841, 13)
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# All of the columns are objects except for the rating column which is float. We will try to change this by changing some of the columns types to numeric ones, while others to strings.

# %% [markdown]
# <h3>Reviews</h3>

# %% [markdown]
# We check first if all of the values are actually numeric.

# %%
apps_df.Reviews.str.isnumeric().sum()
# Out:
# 10840

# %% [markdown]
# There seems to be one value out of the 10841 values that is non-numeric.

# %%
apps_df[~apps_df.Reviews.str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating     Genres Last Updated  \
# 10472  1,000+     Free    0  Everyone            NaN  11-Feb-18       1.0.19
#
#       Current Ver Android Ver
# 10472  4.0 and up         NaN

# %% [markdown]
# This app has a rating of 19.0, which doesn't make any sense. Also, its size, price and category attributes have weird values, therefore we should simply remove this entire row .

# %%
apps_df = apps_df[apps_df.Reviews.str.isnumeric()]

# %% [markdown]
# Finally, we convert the Reviews column's type to numeric

# %%
apps_df.Reviews=pd.to_numeric(apps_df.Reviews)
print(apps_df.dtypes)
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# <h3>Size</h3>

# %% [markdown]
# The size attribute should also be numeric.

# %%
apps_df.Size.value_counts()
# Out:
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
# 15M                    184
# 17M                    160
# 19M                    154
# 26M                    149
# 16M                    149
# 25M                    143
# 20M                    139
# 21M                    138
# 24M                    136
# 10M                    136
# 18M                    133
# 23M                    117
# 22M                    114
# 29M                    103
# 27M                     97
# 28M                     95
# 30M                     84
# 33M                     79
# 3.3M                    77
# 37M                     76
# 35M                     72
# 31M                     70
# 2.9M                    69
# 2.5M                    68
# 2.3M                    68
#                       ...
# 121k                     1
# 511k                     1
# 598k                     1
# 251k                     1
# 351k                     1
# 597k                     1
# 41k                      1
# 857k                     1
# 475k                     1
# 154k                     1
# 186k                     1
# 920k                     1
# 609k                     1
# 544k                     1
# 756k                     1
# 444k                     1
# 74k                      1
# 170k                     1
# 78k                      1
# 862k                     1
# 241k                     1
# 208k                     1
# 887k                     1
# 314k                     1
# 25k                      1
# 313k                     1
# 992k                     1
# 647k                     1
# 50k                      1
# 143k                     1
# Name: Size, Length: 461, dtype: int64

# %% [markdown]
# It seems that most of the values have either the suffix M or the suffix k. We could replace them by 10^6 and 10^3 respectively to make them numeric

# %%
apps_df.Size=apps_df.Size.str.replace('k','e+3')
apps_df.Size=apps_df.Size.str.replace('M','e+6')
apps_df.Size.head()
# Out:
# 0     19e+6
# 1     14e+6
# 2    8.7e+6
# 3     25e+6
# 4    2.8e+6
# Name: Size, dtype: object

# %% [markdown]
# We now make sure that all of the values are numeric before converting the entire column

# %%
def is_numeric(v):
    try:
        float(v)
        return True
    except ValueError:
        return False
    
temp=apps_df.Size.apply(lambda x: is_numeric(x))
apps_df.Size[~temp].value_counts()
# Out:
# Varies with device    1695
# Name: Size, dtype: int64

# %% [markdown]
# There seems to be many rows that have size attributes with the values "Varies with device". We will simply change all of them to NaN

# %%
apps_df.Size=apps_df.Size.replace('Varies with device',np.nan)

# %% [markdown]
# Finally, we convert the column's type to numeric

# %%
apps_df.Size=pd.to_numeric(apps_df.Size)
print(apps_df.dtypes)
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# <h3>Installs</h3>

# %% [markdown]
# We first check the unique values of this column.

# %%
apps_df.Installs.value_counts()
# Out:
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             907
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: Installs, dtype: int64

# %% [markdown]
# All of the values are either pure numbers or numbers prefixed with the sign '+'. We can convert the latter by simply removing the '+' sign.

# %%
apps_df.Installs=apps_df.Installs.apply(lambda x: x.strip('+'))
apps_df.Installs=apps_df.Installs.apply(lambda x: x.replace(',',''))
apps_df.Installs.value_counts()
# Out:
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           907
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               15
# Name: Installs, dtype: int64

# %% [markdown]
# Now that everything seems to be in order, we can safetly convert this column's type to numeric.

# %%
apps_df.Installs=pd.to_numeric(apps_df.Installs)
print(apps_df.dtypes)
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs            int64
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# <h3>Price</h3>

# %% [markdown]
# We first get a feeling of the format of this column

# %%
apps_df.Price.value_counts()
# Out:
# 0           10040
# $0.99         148
# $2.99         129
# $1.99          73
# $4.99          72
# $3.99          63
# $1.49          46
# $5.99          30
# $2.49          26
# $9.99          21
# $6.99          13
# $399.99        12
# $14.99         11
# $4.49           9
# $24.99          7
# $29.99          7
# $3.49           7
# $7.99           7
# $19.99          6
# $5.49           6
# $11.99          5
# $8.99           5
# $12.99          5
# $6.49           5
# $16.99          3
# $10.00          3
# $2.00           3
# $1.00           3
# $9.00           2
# $8.49           2
#             ...
# $3.08           1
# $1.04           1
# $1.26           1
# $37.99          1
# $299.99         1
# $1.20           1
# $25.99          1
# $4.84           1
# $1.59           1
# $15.46          1
# $74.99          1
# $15.99          1
# $109.99         1
# $3.02           1
# $3.90           1
# $1.75           1
# $18.99          1
# $4.80           1
# $3.28           1
# $154.99         1
# $3.61           1
# $4.59           1
# $1.29           1
# $400.00         1
# $394.99         1
# $379.99         1
# $2.50           1
# $4.29           1
# $2.56           1
# $19.90          1
# Name: Price, Length: 92, dtype: int64

# %% [markdown]
# All of the values are either 0 or are numbers prefixed with the dollar sign. We will begin by removing the dollar signs.

# %%
apps_df.Price=apps_df.Price.apply(lambda x: x.strip('$'))
apps_df.Price.value_counts()
# Out:
# 0          10040
# 0.99         148
# 2.99         129
# 1.99          73
# 4.99          72
# 3.99          63
# 1.49          46
# 5.99          30
# 2.49          26
# 9.99          21
# 6.99          13
# 399.99        12
# 14.99         11
# 4.49           9
# 3.49           7
# 7.99           7
# 29.99          7
# 24.99          7
# 5.49           6
# 19.99          6
# 6.49           5
# 12.99          5
# 8.99           5
# 11.99          5
# 10.00          3
# 16.99          3
# 2.00           3
# 1.00           3
# 10.99          2
# 3.95           2
#            ...
# 154.99         1
# 25.99          1
# 389.99         1
# 1.26           1
# 3.08           1
# 15.99          1
# 5.00           1
# 2.56           1
# 4.59           1
# 3.90           1
# 74.99          1
# 15.46          1
# 14.00          1
# 3.02           1
# 1.75           1
# 28.99          1
# 1.04           1
# 4.77           1
# 30.99          1
# 1.76           1
# 19.40          1
# 1.61           1
# 1.97           1
# 1.20           1
# 3.04           1
# 3.61           1
# 3.28           1
# 2.90           1
# 37.99          1
# 1.59           1
# Name: Price, Length: 92, dtype: int64

# %% [markdown]
# Finally, we make sure that all of the values are numeric then convert the column's dtype

# %%
temp=apps_df.Price.apply(lambda x: is_numeric(x))
apps_df.Price[~temp].value_counts()
# Out:
# Series([], Name: Price, dtype: int64)

# %%
apps_df.Price=pd.to_numeric(apps_df.Price)
print(apps_df.dtypes)
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs            int64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# <h2>Duplicates</h2>

# %% [markdown]
# Check if all app names are unique

# %%
apps_df["App"].is_unique
# Out:
# False

# %%
duplicates = apps_df[apps_df["App"].isin(apps_df[apps_df.duplicated()]["App"])]
duplicates.sort_values("App", inplace = False)
# Out:
#                                                      App            Category  \
# 1393                               10 Best Foods for You  HEALTH_AND_FITNESS
# 1407                               10 Best Foods for You  HEALTH_AND_FITNESS
# 2543                          1800 Contacts - Lens Store             MEDICAL
# 2322                          1800 Contacts - Lens Store             MEDICAL
# 2256                          2017 EMRA Antibiotic Guide             MEDICAL
# 2385                          2017 EMRA Antibiotic Guide             MEDICAL
# 1337                        21-Day Meditation Experience  HEALTH_AND_FITNESS
# 1434                        21-Day Meditation Experience  HEALTH_AND_FITNESS
# 2522                              420 BZ Budeze Delivery             MEDICAL
# 7035                              420 BZ Budeze Delivery             MEDICAL
# 1324                        8fit Workouts & Meal Planner  HEALTH_AND_FITNESS
# 1296                        8fit Workouts & Meal Planner  HEALTH_AND_FITNESS
# 2301                             A Manual of Acupuncture             MEDICAL
# 2402                             A Manual of Acupuncture             MEDICAL
# 920                A&E - Watch Full Episodes of TV Shows       ENTERTAINMENT
# 946                A&E - Watch Full Episodes of TV Shows       ENTERTAINMENT
# 4991               A&E - Watch Full Episodes of TV Shows              FAMILY
# 977                A&E - Watch Full Episodes of TV Shows       ENTERTAINMENT
# 2515                                                AAFP             MEDICAL
# 10768                                               AAFP             MEDICAL
# 3787                          ABC News - US & World News  NEWS_AND_MAGAZINES
# 3806                          ABC News - US & World News  NEWS_AND_MAGAZINES
# 2246                                        ASCCP Mobile             MEDICAL
# 2378                                        ASCCP Mobile             MEDICAL
# 280                          Accounting App - Zoho Books            BUSINESS
# 251                          Accounting App - Zoho Books            BUSINESS
# 279                                      AdWords Express            BUSINESS
# 250                                      AdWords Express            BUSINESS
# 2488                             Ada - Your Health Guide             MEDICAL
# 2330                             Ada - Your Health Guide             MEDICAL
# ...                                                  ...                 ...
# 695                             iPair-Meet, Chat, Dating              DATING
# 346                         imo beta free calls and text       COMMUNICATION
# 4123                        imo beta free calls and text       COMMUNICATION
# 383                        imo free video calls and chat       COMMUNICATION
# 4222                       imo free video calls and chat       COMMUNICATION
# 465                        imo free video calls and chat       COMMUNICATION
# 347                        imo free video calls and chat       COMMUNICATION
# 253                            join.me - Simple Meetings            BUSINESS
# 282                            join.me - Simple Meetings            BUSINESS
# 261                            join.me - Simple Meetings            BUSINESS
# 558    muzmatch: Muslim & Arab Singles, Marriage & Da...              DATING
#
# 977       Entertainment    16-Jul-18               3.1.4          4.4 and up
# 2515            Medical    22-Jun-18               2.3.1          5.0 and up
# 10768           Medical    22-Jun-18               2.3.1          5.0 and up
# 3787   News & Magazines     6-Jun-18             3.19.11          5.0 and up
# 3806   News & Magazines     6-Jun-18             3.19.11          5.0 and up
# 2246            Medical     3-Oct-16               2.1.1          2.2 and up
# 2378            Medical     3-Oct-16               2.1.1          2.2 and up
# 280            Business     2-Aug-18              5.20.7          4.1 and up
# 251            Business     2-Aug-18              5.20.7          4.1 and up
# 279            Business    31-Jul-18             2.6.158          4.0 and up
# 250            Business    31-Jul-18             2.6.158          4.0 and up
# 2488            Medical    16-Jul-18              2.25.0          4.4 and up
# 2330            Medical    16-Jul-18              2.25.0          4.4 and up
# ...                 ...          ...                 ...                 ...
# 695              Dating     2-Aug-18               5.0.8          4.1 and up
# 346       Communication     7-Jun-18    9.8.000000010492          4.0 and up
# 4123      Communication     7-Jun-18    9.8.000000010492          4.0 and up
# 383       Communication     8-Jun-18    9.8.000000010501          4.0 and up
# 4222      Communication     8-Jun-18    9.8.000000010501          4.0 and up
# 465       Communication     8-Jun-18    9.8.000000010501          4.0 and up
# 347       Communication     8-Jun-18    9.8.000000010501          4.0 and up
# 253            Business    16-Jul-18           4.3.0.508          4.4 and up
# 282            Business    16-Jul-18           4.3.0.508          4.4 and up
# 261            Business    16-Jul-18           4.3.0.508          4.4 and up
# 558              Dating    24-Jul-18             3.8.75a        4.0.3 and up
# 525              Dating    24-Jul-18             3.8.75a        4.0.3 and up
# 673              Dating    24-Jul-18             3.8.75a        4.0.3 and up
# 6194            Medical    23-Jul-18              3.52.0          5.0 and up
# 2367            Medical     6-Aug-18              3.52.1          5.0 and up
# 2331            Medical     6-Aug-18              3.52.1          5.0 and up
# 1891             Action    14-Nov-17  Varies with device          2.3 and up
# 1659             Action    14-Nov-17  Varies with device          2.3 and up
# 1735             Action    14-Nov-17  Varies with device          2.3 and up
# 1921             Action    14-Nov-17  Varies with device          2.3 and up
# 1757             Action    14-Nov-17  Varies with device          2.3 and up
# 4227             Action    14-Nov-17  Varies with device          2.3 and up
# 3063             Sports    25-Jul-18              6.17.2          4.4 and up
# 3055             Sports    25-Jul-18              6.17.2          4.4 and up
# 2964             Sports    25-Jul-18              6.17.2          4.4 and up
# 3014             Sports    25-Jul-18              6.17.2          4.4 and up
# 3085             Sports    25-Jul-18              6.17.2          4.4 and up
# 3118     Travel & Local     2-Aug-18  Varies with device  Varies with device
# 3202     Travel & Local     2-Aug-18  Varies with device  Varies with device
# 3103     Travel & Local     2-Aug-18  Varies with device  Varies with device
#
# [1073 rows x 13 columns]

# %% [markdown]
# Since there are many apps that are repeated, we could keep the first of each duplicate app and remove the rest

# %%
apps_df.drop_duplicates(subset ="App",keep = "first", inplace = True) 
apps_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 14       3D Color Pixel by Number - Sandbox Art Coloring       ART_AND_DESIGN
# 15                       Learn To Draw Kawaii Characters       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 17                              350 Diy Room Decor Ideas       ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# 20                           Logo Maker - Small Business       ART_AND_DESIGN
# 21             Boys Photo Editor - Six Pack & Men's Suit       ART_AND_DESIGN
# 22               Superheroes Wallpapers | 4K Backgrounds       ART_AND_DESIGN
# 23                                Mcqueen Coloring pages       ART_AND_DESIGN
# 24                           HD Mickey Minnie Wallpapers       ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD       ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring       ART_AND_DESIGN
# 27                                 Animated Photo Editor       ART_AND_DESIGN
# 28                                 Pencil Sketch Drawing       ART_AND_DESIGN
# 29                       Easy Realistic Drawing Tutorial       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10811                                        FR Plus 1.6    AUTO_AND_VEHICLES
# 10812                                      Fr Agnel Pune               FAMILY
# 10813                                     DICT.fr Mobile             BUSINESS
# 10814                               FR: My Secret Pets!                FAMILY
# 10815                          Golden Dictionary (FR-AR)  BOOKS_AND_REFERENCE
# 10816                                 FieldBi FR Offline             BUSINESS
# 10817                               HTC Sense Input - FR                TOOLS
# 10818                               Gold Quote - Gold.fr              FINANCE
# 10819                                          Fanfic-FR  BOOKS_AND_REFERENCE
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10821                                            Poop FR               FAMILY
# 10822                                          PLMGSS FR         PRODUCTIVITY
# 10823                                       List iptv FR        VIDEO_PLAYERS
# 10824                                          Cardio-FR              MEDICAL
# 10825                                 Naruto & Boruto FR               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10827                                 Fr Agnel Ambarnath               FAMILY
# 10828                            Manga-FR - Anime Vostfr               COMICS
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10830                                  News Minecraft.fr   NEWS_AND_MAGAZINES
# 10831                           payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                           FR Tides              WEATHER
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10835                                           FR Forms             BUSINESS
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews        Size  Installs  Type  Price Content Rating  \
# 0         4.1      159  19000000.0     10000  Free    0.0       Everyone
# 1         3.9      967  14000000.0    500000  Free    0.0       Everyone
# 2         4.7    87510   8700000.0   5000000  Free    0.0       Everyone
# 3         4.5   215644  25000000.0  50000000  Free    0.0           Teen
# 4         4.3      967   2
0      5000  Free    0.0       Everyone
# 10837     5.0        4   3600000.0       100  Free    0.0       Everyone
# 10838     NaN        3   9500000.0      1000  Free    0.0       Everyone
# 10839     4.5      114         NaN      1000  Free    0.0     Mature 17+
# 10840     4.5   398307  19000000.0  10000000  Free    0.0       Everyone
#
#                                 Genres Last Updated         Current Ver  \
# 0                         Art & Design     7-Jan-18               1.0.0
# 1            Art & Design;Pretend Play    15-Jan-18               2.0.0
# 2                         Art & Design     1-Aug-18               1.2.4
# 3                         Art & Design     8-Jun-18  Varies with device
# 4              Art & Design;Creativity    20-Jun-18                 1.1
# 5                         Art & Design    26-Mar-17                   1
# 6                         Art & Design    26-Apr-18                 1.1
# 7                         Art & Design    14-Jun-18            6.1.61.1
# 8                         Art & Design    20-Sep-17               2.9.2
# 9              Art & Design;Creativity     3-Jul-18                 2.8
# 10                        Art & Design    27-Oct-17               1.0.4
# 11                        Art & Design    31-Jul-18              1.0.15
# 12                        Art & Design     2-Apr-18                 3.8
# 13                        Art & Design    26-Jun-18               1.0.4
# 14                        Art & Design     3-Aug-18               1.2.3
# 15                        Art & Design     6-Jun-18                 NaN
# 16                        Art & Design    31-Jul-18                 3.1
# 17                        Art & Design     7-Nov-17                   1
# 18                        Art & Design     3-Aug-18               2.2.5
# 19                        Art & Design    30-Jul-18               5.5.4
# 20                        Art & Design    20-Apr-18                   4
# 21                        Art & Design    20-Mar-18                 1.1
# 22                        Art & Design    12-Jul-18             2.2.6.2
# 23     Art & Design;Action & Adventure     7-Mar-18               1.0.0
# 24                        Art & Design     7-Jul-18               1.1.3
# 25                        Art & Design    25-Apr-18                 1.5
# 26             Art & Design;Creativity    11-Oct-17               1.0.8
# 27                        Art & Design    21-Mar-18                1.03
# 28                        Art & Design    12-Jul-18                   6
# 29                        Art & Design    22-Aug-17                   1
# ...                                ...          ...                 ...
# 10811                  Auto & Vehicles    24-Jul-18               1.3.6
# 10812                        Education    13-Jun-18              2.0.20
# 10813                         Business    17-Jul-18              2.1.10
# 10814                    Entertainment     3-Jun-15               1.3.1
# 10815                Books & Reference    19-Jul-18             7.0.4.6
# 10816                         Business     6-Aug-18               2.1.8
# 10817                            Tools    30-Oct-15          1.0.612928
# 10818                          Finance    19-May-16                 2.3
# 10819                Books & Reference     5-Aug-17               0.3.4
# 10820                        Education    27-Jun-18               3.8.0
# 10821                    Entertainment    29-May-18                   1
# 10822                     Productivity     1-Dec-17                   1
# 10823          Video Players & Editors    22-Apr-18                   1
# 10824                          Medical    31-Jul-18               2.2.2
# 10825                           Social     2-Feb-18                   1
# 10826                           Social    23-Mar-18  Varies with device
# 10827                        Education    13-Jun-18              2.0.20
# 10828                           Comics    15-May-17               2.0.1
# 10829                Books & Reference    19-Jun-16                2.96
# 10830                 News & Magazines    20-Jan-14                 1.5
# 10831                Maps & Navigation    13-Jun-18           2.0.148.0
# 10832                          Weather    16-Feb-14                   6
# 10833                Books & Reference    23-Mar-14                 0.8
# 10834                        Education    18-Jun-17               1.0.0
# 10835                         Business    29-Sep-16               1.1.5
# 10836                        Education    25-Jul-17                1.48
# 10837                        Education     6-Jul-18                   1
# 10838                          Medical    20-Jan-17                   1
# 10839                Books & Reference    19-Jan-15  Varies with device
# 10840                        Lifestyle    25-Jul-18  Varies with device
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# 5              2.3 and up
# 6            4.0.3 and up
# 7              4.2 and up
# 8              3.0 and up
# 9            4.0.3 and up
# 10             4.1 and up
# 11             4.0 and up
# 12             4.1 and up
# 13             4.4 and up
# 14             2.3 and up
# 15             4.2 and up
# 16             4.1 and up
# 17             2.3 and up
# 18           4.0.3 and up
# 19             4.1 and up
# 20             4.1 and up
# 21           4.0.3 and up
# 22           4.0.3 and up
# 23             4.1 and up
# 24             4.1 and up
# 25             3.0 and up
# 26           4.0.3 and up
# 27           4.0.3 and up
# 28             2.3 and up
# 29             2.3 and up
# ...                   ...
# 10811         4.4W and up
# 10812        4.0.3 and up
# 10813          4.1 and up
# 10814          3.0 and up
# 10815          4.2 and up
# 10816          4.1 and up
# 10817          5.0 and up
# 10818          2.2 and up
# 10819          4.1 and up
# 10820          4.1 and up
# 10821        4.0.3 and up
# 10822          4.4 and up
# 10823        4.0.3 and up
# 10824          4.4 and up
# 10825          4.0 and up
# 10826  Varies with device
# 10827        4.0.3 and up
# 10828          4.0 and up
# 10829          4.1 and up
# 10830          1.6 and up
# 10831          4.0 and up
# 10832          2.1 and up
# 10833          2.2 and up
# 10834          4.1 and up
# 10835          4.0 and up
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [9659 rows x 13 columns]

# %% [markdown]
# <h2>Cleaning Data</h2>

# %% [markdown]
# We will now try to look for any corrupted/abnormal data and deal with it.

# %% [markdown]
# <h3>Category</h3>

# %% [markdown]
# We list all of the unique attributes and see if something doesn't fit

# %%
apps_df.Category.unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %% [markdown]
# Everything seems to be in order

# %% [markdown]
# <h3> Size </h3>

# %%
# Find the number of nan values
print("Nan Values = ", apps_df["Size"].isnull().sum())
# Out:
# Nan Values =  1227

# %% [markdown]
# Since we would need the size values for each application to formulate our questions, we would omit the nan values.

# %%
# assign the data frame with the values that does not contain null in the coulmn 'Size'
apps_df = apps_df[pd.notnull(apps_df['Size'])]

# Checking the result
print("Nan Values = ", apps_df["Size"].isnull().sum())
# Out:
# Nan Values =  0

# %% [markdown]
# <h3>Rating</h3>

# %%
print("Min rating = ",apps_df["Rating"].min())
print("Max rating = ",apps_df["Rating"].max())
print("Nan Values = ", apps_df["Rating"].isnull().sum())
# Out:
# Min rating =  1.0
# Max rating =  5.0
# Nan Values =  1405

# %% [markdown]
# All ratings seem to be within range, however some ratings has a nan value, which could mean that they are not rated yet. That we can consider them as 0 rating.

# %%
# making a copy of the data frame to avoid the SettingWithCopyWarning warning
apps_df = apps_df.copy()

# replacing the 'Rating' coulmn with the one with zeros instead of Nan
apps_df['Rating'] = apps_df['Rating'].fillna(0)

# Checking the result
print("Nan Values = ", apps_df["Rating"].isnull().sum())
# Out:
# Nan Values =  0

# %% [markdown]
# <h3>Type</h3>

# %%
apps_df.Type.value_counts()
# Out:
# Free    7747
# Paid     685
# Name: Type, dtype: int64

# %% [markdown]
# Nothing wrong here!

# %% [markdown]
# <h2>Content Rating</h2>

# %%
apps_df["Content Rating"].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %% [markdown]
# We would represent every rating category by a number representation according to the following table :-
#
# | Rating Category | # |
# |-----------------|---|
# | Everyone        | 1 |
# | Teen            | 2 |
# | Everyone 10+    | 3 |
# | Mature 17+      | 4 |
# | Adults only 18+ | 5 |
# | Unrated         | 0 |

# %%
# We replace by creating a dictionary with the replacment as key/value pair, and pass it to the replace method.

replacing_Dict = { 'Everyone': 1, 'Teen': 2, 'Everyone 10+': 3, 'Mature 17+': 4, 'Adults only 18+': 5, 'Unrated': 0 }
apps_df["Content Rating"]=apps_df["Content Rating"].replace(to_replace=replacing_Dict)

# %% [markdown]
# <h2>Genres</h2>

# %%
apps_df.Genres.unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education', 'Education;Creativity', 'Education;Education',
#        'Education;Action & Adventure', 'Education;Pretend Play',
#        'Education;Brain Games', 'Entertainment',
#        'Entertainment;Brain Games', 'Entertainment;Music & Video',
#        'Events', 'Finance', 'Food & Drink', 'Health & Fitness',
#        'House & Home', 'Libraries & Demo', 'Lifestyle',
#        'Lifestyle;Pretend Play', 'Adventure;Action & Adventure', 'Arcade',
#        'Casual', 'Card', 'Casual;Pretend Play', 'Strategy', 'Action',
#        'Puzzle', 'Sports', 'Word', 'Racing', 'Casual;Creativity',
#        'Simulation', 'Adventure', 'Board', 'Trivia', 'Role Playing',
#        'Simulation;Education', 'Action;Action & Adventure',
#        'Casual;Brain Games', 'Simulation;Action & Adventure',
#        'Educational;Creativity', 'Puzzle;Brain Games',
#        'Educational;Education', 'Educational;Brain Games',
#        'Educational;Pretend Play', 'Casual;Action & Adventure',
#        'Entertainment;Education', 'Casual;Education',
#        'Music;Music & Video', 'Arcade;Pretend Play',
#        'Simulation;Pretend Play', 'Puzzle;Creativity',
#        'Racing;Action & Adventure', 'Educational;Action & Adventure',
#        'Arcade;Action & Adventure', 'Entertainment;Action & Adventure',
#        'Puzzle;Action & Adventure', 'Role Playing;Action & Adventure',
#        'Strategy;Action & Adventure', 'Music & Audio;Music & Video',
#        'Health & Fitness;Education', 'Adventure;Education',
#        'Board;Brain Games', 'Board;Action & Adventure',
#        'Board;Pretend Play', 'Casual;Music & Video',
#        'Education;Music & Video', 'Role Playing;Pretend Play',
#        'Entertainment;Pretend Play', 'Video Players & Editors;Creativity',
#        'Card;Action & Adventure', 'Medical', 'Social', 'Shopping',
#        'Photography', 'Travel & Local',
#        'Travel & Local;Action & Adventure', 'Tools', 'Personalization',
#        'Productivity', 'Parenting', 'Parenting;Education',
#        'Parenting;Brain Games', 'Parenting;Music & Video', 'Weather',
#        'Video Players & Editors', 'News & Magazines', 'Maps & Navigation',
#        'Health & Fitness;Action & Adventure', 'Music', 'Educational',
#        'Casino', 'Adventure;Brain Games',
#        'Video Players & Editors;Music & Video', 'Trivia;Education',
#        'Entertainment;Creativity', 'Sports;Action & Adventure',
#        'Books & Reference;Creativity', 'Books & Reference;Education',
#        'Puzzle;Education', 'Role Playing;Education',
#        'Role Playing;Brain Games', 'Strategy;Education',
#        'Racing;Pretend Play', 'Strategy;Creativity'], dtype=object)

# %% [markdown]
# Some of the values here seem to be composed of multiple labels, which are separated by a semicolon (ex: 'Sports;Action & Adventure'). We can change divide this column into 2 columns: 'Primary_Genres' & 'Secondary_Genres'

# %%
# pd.concat([apps_df, apps_df["Genres"].str.split(';', expand=True)], axis=1)
split = apps_df["Genres"].str.split(';', expand=True)
# split = split.rename(columns={0:"Primary Genres",1:"Secondary Genres"})
split
# Out:
#                              0                   1
# 0                 Art & Design                None
# 1                 Art & Design        Pretend Play
# 2                 Art & Design                None
# 3                 Art & Design                None
# 4                 Art & Design          Creativity
# 5                 Art & Design                None
# 6                 Art & Design                None
# 7                 Art & Design                None
# 8                 Art & Design                None
# 9                 Art & Design          Creativity
# 10                Art & Design                None
# 11                Art & Design                None
# 12                Art & Design                None
# 13                Art & Design                None
# 14                Art & Design                None
# 15                Art & Design                None
# 16                Art & Design                None
# 17                Art & Design                None
# 18                Art & Design                None
# 19                Art & Design                None
# 20                Art & Design                None
# 21                Art & Design                None
# 22                Art & Design                None
# 23                Art & Design  Action & Adventure
# 24                Art & Design                None
# 25                Art & Design                None
# 26                Art & Design          Creativity
# 27                Art & Design                None
# 28                Art & Design                None
# 29                Art & Design                None
# ...                        ...                 ...
# 10809                 Strategy                None
# 10810                 Business                None
# 10811          Auto & Vehicles                None
# 10812                Education                None
# 10813                 Business                None
# 10814            Entertainment                None
# 10815        Books & Reference                None
# 10816                 Business                None
# 10817                    Tools                None
# 10818                  Finance                None
# 10819        Books & Reference                None
# 10820                Education                None
# 10821            Entertainment                None
# 10822             Productivity                None
# 10823  Video Players & Editors                None
# 10824                  Medical                None
# 10825                   Social                None
# 10827                Education                None
# 10828                   Comics                None
# 10829        Books & Reference                None
# 10830         News & Magazines                None
# 10831        Maps & Navigation                None
# 10832                  Weather                None
# 10833        Books & Reference                None
# 10834                Education                None
# 10835                 Business                None
# 10836                Education                None
# 10837                Education                None
# 10838                  Medical                None
# 10840                Lifestyle                None
#
# [8432 rows x 2 columns]

# %%
apps_df = pd.concat([apps_df,split],axis=1)
apps_df = apps_df.rename(columns={0:"Primary Genres",1:"Secondary Genres"})
apps_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews        Size  Installs  Type  Price  Content Rating  \
# 0      159  19000000.0     10000  Free    0.0               1
# 1      967  14000000.0    500000  Free    0.0               1
# 2    87510   8700000.0   5000000  Free    0.0               1
# 3   215644  25000000.0  50000000  Free    0.0               2
# 4      967   2800000.0    100000  Free    0.0               1
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play    15-Jan-18               2.0.0  4.0.3 and up
# 2               Art & Design     1-Aug-18               1.2.4  4.0.3 and up
# 3               Art & Design     8-Jun-18  Varies with device    4.2 and up
# 4    Art & Design;Creativity    20-Jun-18                 1.1    4.4 and up
#
#   Primary Genres Secondary Genres
# 0   Art & Design             None
# 1   Art & Design     Pretend Play
# 2   Art & Design             None
# 3   Art & Design             None
# 4   Art & Design       Creativity

# %% [markdown]
# <h3>Last Updated</h3>

# %%
apps_df["Last Updated"].unique()
# Out:
# array(['7-Jan-18', '15-Jan-18', '1-Aug-18', ..., '20-Jan-14', '16-Feb-14',
#        '23-Mar-14'], dtype=object)

# %% [markdown]
# Nothing seems wrong here!

# %% [markdown]
# <h3>Current Ver</h3>

# %%
apps_df["Current Ver"].unique()
# Out:
# array(['1.0.0', '2.0.0', '1.2.4', ..., '1.0.612928', '0.3.4', '2.0.148.0'],
#       dtype=object)

# %% [markdown]
# Aside from the fact that some values have the vale 'Varies with device', nothing seems to be wrong.

# %% [markdown]
# <h3>Android Ver</h3>

# %%
apps_df["Android Ver"].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.2 and up',
#        '5.0 and up', '6.0 and up', '1.6 and up', '2.1 and up',
#        '5.1 and up', '1.5 and up', '7.0 and up', '4.3 and up',
#        '4.0.3 - 7.1.1', '2.0 and up', '2.3.3 and up',
#        'Varies with device', '3.2 and up', '4.4W and up', '7.1 and up',
#        '7.0 - 7.1.1', '8.0 and up', '5.0 - 8.0', '3.1 and up',
#        '2.0.1 and up', '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up',
#        '2.2 - 7.1.1', '5.0 - 7.1.1'], dtype=object)

# %% [markdown]
# Nothing out of the ordinary!

# %% [markdown]
# <h2>Finish</h2>

# %% [markdown]
# Finally, we save the dataframe into a new csv file

# %%
apps_df.to_csv("./data/googleplaystore_clean.csv",index=False)
